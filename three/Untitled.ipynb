# %%
 import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r'C:\Users\hp zbook\homewok\three\MLS.csv')
df
# Out:
#                Location  CompIndex  CompBenchmark  CompYoYChange  \
# 0     Adjala-Tosorontio      143.7       510000.0          12.00
# 1     Adjala-Tosorontio      140.8       499700.0          13.82
# 2     Adjala-Tosorontio      142.7       506400.0          15.83
# 3     Adjala-Tosorontio      138.4       491100.0          11.08
# 4     Adjala-Tosorontio      145.4       516000.0          16.51
# ...                 ...        ...            ...            ...
# 5086        York Region      287.0       970300.0          11.76
# 5087        York Region      289.5       978700.0          12.56
# 5088        York Region      294.9       997000.0          13.34
# 5089        York Region      309.9      1047700.0          17.16
# 5090        York Region      324.1      1095700.0          19.82
#
#       SFDetachIndex  SFDetachBenchmark  SFDetachYoYChange       Date
# 0             143.7           510000.0              12.00   7/1/2015
# ...

# %%
df.CompBenchmark.median()
# Out:
# 726500.0

# %%
df.CompBenchmark=df.CompBenchmark.fillna(df.CompBenchmark.median())
df
# Out:
#                Location  CompIndex  CompBenchmark  CompYoYChange  \
# 0     Adjala-Tosorontio      143.7       510000.0          12.00
# 1     Adjala-Tosorontio      140.8       499700.0          13.82
# 2     Adjala-Tosorontio      142.7       506400.0          15.83
# 3     Adjala-Tosorontio      138.4       491100.0          11.08
# 4     Adjala-Tosorontio      145.4       516000.0          16.51
# ...                 ...        ...            ...            ...
# 5086        York Region      287.0       970300.0          11.76
# 5087        York Region      289.5       978700.0          12.56
# 5088        York Region      294.9       997000.0          13.34
# 5089        York Region      309.9      1047700.0          17.16
# 5090        York Region      324.1      1095700.0          19.82
#
#       SFDetachIndex  SFDetachBenchmark  SFDetachYoYChange       Date
# 0             143.7           510000.0              12.00   7/1/2015
# ...

# %%
x=df.drop('CompIndex',axis='columns')
x
# Out:
#                Location  CompBenchmark  CompYoYChange  SFDetachIndex  \
# 0     Adjala-Tosorontio       510000.0          12.00          143.7
# 1     Adjala-Tosorontio       499700.0          13.82          140.8
# 2     Adjala-Tosorontio       506400.0          15.83          142.7
# 3     Adjala-Tosorontio       491100.0          11.08          138.4
# 4     Adjala-Tosorontio       516000.0          16.51          145.4
# ...                 ...            ...            ...            ...
# 5086        York Region       970300.0          11.76          292.0
# 5087        York Region       978700.0          12.56          295.2
# 5088        York Region       997000.0          13.34          301.7
# 5089        York Region      1047700.0          17.16          318.6
# 5090        York Region      1095700.0          19.82          334.4
#
#       SFDetachBenchmark  SFDetachYoYChange       Date
# 0              510000.0              12.00   7/1/2015
# ...

# %%
y=df.CompIndex
y
# Out:
# 0       143.7
# 1       140.8
# 2       142.7
# 3       138.4
# 4       145.4
#         ...
# 5086    287.0
# 5087    289.5
# 5088    294.9
# 5089    309.9
# 5090    324.1
# Name: CompIndex, Length: 5091, dtype: float64

# %%
print(df.iloc[0])
# Out:
# Location             Adjala-Tosorontio
# CompIndex                        143.7
# CompBenchmark                   510000
# CompYoYChange                       12
# SFDetachIndex                    143.7
# SFDetachBenchmark               510000
# SFDetachYoYChange                   12
# Date                          7/1/2015
# Name: 0, dtype: object

# %%
model.copy_X
# Out:
# True
